# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from lclu import LCZ

# %%
lcz_path = os.path.join ('data','lcz','lcz_filter_v1.tif')

# %%
x= LCZ(lcz_path)

# %%
box = ((30.4, 30.8), (29.7, 31.8))
ax, content, w, hist = x.get_region(box, fig_size=(10,8))

# %%
box = ((-25.7, 27.7), (-26.6, 28.5))
ax, content, w, hist = x.get_region(box, fig_size=(10,8))

# %%
box = ((37.1, 35.2), (36.9, 35.5))
ax, content, w, hist = x.get_region(box, fig_size=(10,8))

# %%
box = ((41.02, 37.85), (40.92, 38.03))
ax, content, w, hist = x.get_region(box, fig_size=(10,8))

# %%
box = ((41.02, 39.65), (40.95, 39.80))
ax, content, w, hist = x.get_region(box, fig_size=(10,8))

# %%
box = ((38.67, 27.28), (38.58, 27.49))
ax, content, w, hist = x.get_region(box, fig_size=(10,8))
