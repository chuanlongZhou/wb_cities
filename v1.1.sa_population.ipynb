# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.statssa.gov.za/?page_id=993&id=city-of-johannesburg-municipality"
target = "body > div > div:nth-child(4) > div.span3 > table > tbody > tr > td > div > ul > li > a"

wb_data = requests.get(url)
print(wb_data.status_code)
soup = BeautifulSoup(wb_data.text, 'lxml')
# Out:
# 200

# %%
target = "body > div > div:nth-child(4) > div.span3 > table > tbody > tr > td > div > ul > li > a"
res = soup.select(target)
for i in res:
	print(i.text, i.get("href"))
# Out:
# Alexandra ?page_id=4286&id=11305
# Chartwell ?page_id=4286&id=11302
# City of Johannesburg NU ?page_id=4286&id=11293
# Dainfern ?page_id=4286&id=11303
# Diepsloot ?page_id=4286&id=11294
# Drie Ziek ?page_id=4286&id=11326
# Ebony Park ?page_id=4286&id=11298
# Ennerdale ?page_id=4286&id=11324
# Farmall ?page_id=4286&id=11308
# Itsoseng ?page_id=4286&id=11312
# Ivory Park ?page_id=4286&id=11297
# Johannesburg ?page_id=4286&id=11306
# Kaalfontein ?page_id=4286&id=11296
# Kagiso ?page_id=4286&id=11315
# Kanana Park ?page_id=4286&id=11330
# Lakeside ?page_id=4286&id=11328
# Lanseria ?page_id=4286&id=11310
# Lawley ?page_id=4286&id=11329
# Lehae ?page_id=4286&id=11320
# Lenasia ?page_id=4286&id=11319
# Lenasia South ?page_id=4286&id=11323
# Lucky 7 ?page_id=4286&id=11311
# Malatjie ?page_id=4286&id=11292
# Mayibuye ?page_id=4286&id=11300
# Midrand ?page_id=4286&id=11295
# Millgate Farm ?page_id=4286&id=11309
# Orange Farm ?page_id=4286&id=11325
# Poortjie ?page_id=4286&id=11331
# ...

# %%
url2 = "https://www.statssa.gov.za/?page_id=4286&id=11301"
wb_data = requests.get(url)
print(wb_data.status_code)
soup = BeautifulSoup(wb_data.text, 'lxml')

# %%
target = "body > div > div:nth-child(5) > div.span3 > table:nth-child(2) > tbody > tr:nth-child(1) > td.muted"
res = soup.select(target)
res
# Out:
# []

# %%
soup.find("table")
# Out:
# <table class="table table-hover" id="ranking_table">
# <caption>
# <div class="pull-right">
# <div class="input-prepend">
# <span class="add-on" style="text-shadow:none;">Rank By:</span>
# ...
